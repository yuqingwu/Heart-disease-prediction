# %% [markdown]
# # Heart disease prediction

# %% [markdown]
# ## Project description

# %% [markdown]
# Heart disease is a common and potentially life-threatening condition that affects millions of people worldwide. Early detection and accurate prediction of heart disease are critical for timely intervention and improved patient outcomes. The project aims to predict a person's likelihood of developing heart disease based on various health-related characteristics. Predictive models utilize machine learning algorithms to analyze and interpret input data.

# %% [markdown]
# ## Dataset description

# %% [markdown]
# This data set dates from 1988 and consists of four databases: Cleveland, Hungary, Switzerland, and Long Beach V. It contains 76 attributes, including the predicted attribute, but all published experiments refer to using a subset of 14 of them. The "target" field refers to the presence of heart disease in the patient. It is integer valued 0 = no disease and 1 = disease

# %% [markdown]
# #### Columns description

# %% [markdown]
# 1. age - The person’s age in years
# 2. sex - The person’s sex: 1 = male, 0 = female
# 3. cp - chest pain type (4 values): 0 = asymptomatic, 1 = atypical angina, 2 = non-angina pain, 3 = typical angina
# 4. trestbps - resting blood pressure (in min Hg on admission to the hospital)
# 5. chol - serum cholestoral in mg/dl
# 6. fbs - fasting blood sugar > 120 mg/dl: 1 = true, 0 = false
# 7. restecg - resting electrocardiographic results (3 values): 0 - showing probable or definite left ventricular hypertrophy by Estes’ criteria, 1 = normal, 2 = having ST-T wave abnormality
# 8. thalach - maximum heart rate achieved
# 9. exang - exercise induced angina: 1 = yes, 0 = no
# 10. oldpeak - ST depression induced by exercise relative to rest
# 11. slope - the slope of the peak exercise ST segment: 0 = downsloping, 1 = flat, 2 = uploping
# 12. ca - number of major vessels (0-3) colored by flourosopy
# 13. thal - a blood disorder called thalassemia: 0 = NULL (dropped from the dataset previously), 1 = fixed defect (no blood flow in some part of the heart), 2 = normal blood flow, 3 = reversible defect (a blood flow is observed but it is not normal)

# %% [markdown]
# ## Dependencies loading

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Project setup

# %%
data_path = "../data"

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Data loading

# %%
df = pd.read_csv(f"{data_path}/heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# #### Shape of dataset

# %%
df.shape
# Out:
# (1025, 14)

# %% [markdown]
# ### Data processing

# %% [markdown]
# #### encode the features into categorical variables

# %%
# converting features to categorical features 

df['cp'][df['cp'] == 0] = 'asymptomatic'
df['cp'][df['cp'] == 1] = 'atypical angina'
df['cp'][df['cp'] == 2] = 'non-anginal pain'
df['cp'][df['cp'] == 3] = 'typical angina'

df['restecg'][df['restecg'] == 0] = 'left ventricular hypertrophy'
df['restecg'][df['restecg'] == 1] = 'normal'
df['restecg'][df['restecg'] == 2] = 'ST-T wave abnormality'

df['slope'][df['slope'] == 0] = 'downsloping'
df['slope'][df['slope'] == 1] = 'flat'
df['slope'][df['slope'] == 2] = 'upsloping'

df['thal'][df['thal'] == 0] = 'null'
df['thal'][df['thal'] == 1] = 'fixed defect'
df['thal'][df['thal'] == 2] = 'normal'
df['thal'][df['thal'] == 3] = 'reversable defect'

df["sex"] = df.sex.apply(lambda  x:'Male' if x==1 else 'Female')
df["exang"] = df.exang.apply(lambda  x:'yes' if x==1 else 'no')

# %%
df['cp'].value_counts()
# Out:
# asymptomatic        497
# non-anginal pain    284
# atypical angina     167
# typical angina       77
# Name: cp, dtype: int64

# %%
df['restecg'].value_counts()
# Out:
# normal                          513
# left ventricular hypertrophy    497
# ST-T wave abnormality            15
# Name: restecg, dtype: int64

# %%
df['slope'].value_counts()
# Out:
# flat           482
# upsloping      469
# downsloping     74
# Name: slope, dtype: int64

# %%
df['thal'].value_counts()
# Out:
# normal               544
# reversable defect    410
# fixed defect          64
# null                   7
# Name: thal, dtype: int64

# %%
#dropping row with thal is null
df.drop(df[df.thal =='null'].index, inplace=True)
#checking distribution
df['thal'].value_counts()
# Out:
# normal               544
# reversable defect    410
# fixed defect          64
# Name: thal, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      709
# Female    309
# Name: sex, dtype: int64

# %%
df['exang'].value_counts()
# Out:
# no     677
# yes    341
# Name: exang, dtype: int64

# %%
df.head()
# Out:
#    age     sex            cp  trestbps  chol  fbs  \
# 0   52    Male  asymptomatic       125   212    0
# 1   53    Male  asymptomatic       140   203    1
# 2   70    Male  asymptomatic       145   174    0
# 3   61    Male  asymptomatic       148   203    0
# 4   62  Female  asymptomatic       138   294    1
#
#                         restecg  thalach exang  oldpeak        slope  ca  \
# 0                        normal      168    no      1.0    upsloping   2
# 1  left ventricular hypertrophy      155   yes      3.1  downsloping   0
# 2                        normal      125   yes      2.6  downsloping   0
# 3                        normal      161    no      0.0    upsloping   1
# 4                        normal      106    no      1.9         flat   3
#
#                 thal  target
# 0  reversable defect       0
# 1  reversable defect       0
# 2  reversable defect       0
# 3  reversable defect       0
# 4             normal       0

# %%
df.shape
# Out:
# (1018, 14)

# %% [markdown]
# #### Types of data

# %% [markdown]
# 6 fetures are object and 6 fetures are numeric

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1018 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1018 non-null   int64
#  1   sex       1018 non-null   object
#  2   cp        1018 non-null   object
#  3   trestbps  1018 non-null   int64
#  4   chol      1018 non-null   int64
#  5   fbs       1018 non-null   int64
#  6   restecg   1018 non-null   object
#  7   thalach   1018 non-null   int64
#  8   exang     1018 non-null   object
#  9   oldpeak   1018 non-null   float64
#  10  slope     1018 non-null   object
#  11  ca        1018 non-null   int64
#  12  thal      1018 non-null   object
#  13  target    1018 non-null   int64
# dtypes: float64(1), int64(7), object(6)
# memory usage: 119.3+ KB

# %% [markdown]
# #### Checking the missing value

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# #### Description

# %%
# summary statistics of numerical columns
df.describe()
# Out:
#                age     trestbps         chol          fbs      thalach  \
# count  1018.000000  1018.000000  1018.000000  1018.000000  1018.000000
# mean     54.447937   131.636542   246.253438     0.146365   149.187623
# std       9.101835    17.574327    51.676406     0.353646    23.006116
# min      29.000000    94.000000   126.000000     0.000000    71.000000
# 25%      48.000000   120.000000   211.000000     0.000000   132.000000
# 50%      56.000000   130.000000   240.000000     0.000000   152.000000
# 75%      61.000000   140.000000   275.750000     0.000000   166.000000
# max      77.000000   200.000000   564.000000     1.000000   202.000000
#
#            oldpeak           ca       target
# count  1018.000000  1018.000000  1018.000000
# mean      1.074951     0.759332     0.513752
# std       1.177640     1.032432     0.500057
# min       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000
# 50%       0.800000     0.000000     1.000000
# 75%       1.800000     1.000000     1.000000
# max       6.200000     4.000000     1.000000

# %%
# summary statistics of categorical columns
df.describe(include =['O'])
# Out:
#          sex            cp restecg exang slope    thal
# count   1018          1018    1018  1018  1018    1018
# unique     2             4       3     2     3       3
# top     Male  asymptomatic  normal    no  flat  normal
# freq     709           493     509   677   478     544

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Distribution of Heart disease (target variable)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=False, figsize=(14,6))

ax1 = df['target'].value_counts().plot.pie( x="Heart disease" ,y ='no.of patients', 
                   autopct = "%1.0f%%",labels=["Heart Disease","Normal"], startangle = 60,ax=ax1);
ax1.set(title = 'Percentage of Heart disease patients in Dataset')

ax2 = df["target"].value_counts().plot(kind="barh" ,ax =ax2)
for i,j in enumerate(df["target"].value_counts().values):
    ax2.text(.5,i,j,fontsize=12)
ax2.set(title = 'No. of Heart disease patients in Dataset')
plt.show()

# %% [markdown]
# The dataset is balanced having 526 heart disease patients and 499 normal patients

# %% [markdown]
# ### Checking Gender & Age Distribution

# %%
plt.figure(figsize=(18,12))
plt.subplot(221)
df["sex"].value_counts().plot.pie(autopct = "%1.0f%%",colors = sns.color_palette("prism",5),startangle = 60,labels=["Male","Female"],
wedgeprops={"linewidth":2,"edgecolor":"k"},explode=[.1,.1],shadow =True)
plt.title("Distribution of Gender")
plt.subplot(222)
ax= sns.distplot(df['age'], rug=True)
plt.title("Age wise distribution")
plt.show()

# %% [markdown]
# As we can see from above plot, in this dataset males percentage is way too higher than females where as average age of patients is around 58

# %%
# creating separate df for normal and heart patients

attr_1=df[df['target']==1]

attr_0=df[df['target']==0]

# plotting normal patients
fig = plt.figure(figsize=(15,5))
ax1 = plt.subplot2grid((1,2),(0,0))
sns.distplot(attr_0['age'])
plt.title('AGE DISTRIBUTION OF NORMAL PATIENTS', fontsize=15, weight='bold')

ax2 = plt.subplot2grid((1,2),(0,1))  # Use a different variable name (ax2) to avoid conflict
sns.countplot(data=attr_0, x='sex')  # Specify 'data' parameter and use 'x' to specify the column
plt.title('GENDER DISTRIBUTION OF NORMAL PATIENTS', fontsize=15, weight='bold')
plt.show()


# plotting heart patients
fig = plt.figure(figsize=(15,5))
ax1 = plt.subplot2grid((1,2),(0,0))
sns.distplot(attr_1['age'])
plt.title('AGE DISTRIBUTION OF HEART DISEASE PATIENTS', fontsize=15, weight='bold')

ax2 = plt.subplot2grid((1,2),(0,1))  # Use a different variable name (ax2) to avoid conflict
sns.countplot(data=attr_1, x='sex', palette='viridis')  # Specify 'data' parameter and use 'x' to specify the column
plt.title('GENDER DISTRIBUTION OF HEART DISEASE PATIENTS', fontsize=15, weight='bold')
plt.show()

# %% [markdown]
# More males accounts for heart disease in comparison to females whereas mean age for heart disease patients is around 52 to 54 years

# %% [markdown]
# ### Distribution of Chest Pain Type

# %%
# plotting normal patients
fig = plt.figure(figsize=(15, 5))
ax1 = plt.subplot2grid((1, 2), (0, 0))
sns.countplot(data=attr_0, x='cp')  # Specify 'data' parameter and use 'x' to specify the column
plt.title('CHEST PAIN OF NORMAL PATIENTS', fontsize=15, weight='bold')

# plotting heart patients
ax2 = plt.subplot2grid((1, 2), (0, 1))
sns.countplot(data=attr_1, x='cp', palette='viridis')  # Specify 'data' parameter and use 'x' to specify the column
plt.title('CHEST PAIN OF HEART PATIENTS', fontsize=15, weight='bold')
plt.show()

# %%
#Exploring the Heart Disease patients based on Chest Pain Type
plot_criteria= ['cp', 'target']
cm = sns.light_palette("red", as_cmap=True)
(round(pd.crosstab(df[plot_criteria[0]], df[plot_criteria[1]], normalize='columns') * 100,2)).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row0_col0 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row0_col1 {
#             background-color:  #ff8282;
#             color:  #000000;
#         }    #T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row1_col0 {
#             background-color:  #ffe1e1;
#             color:  #000000;
#         }    #T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row1_col1 {
#             background-color:  #ff7272;
#             color:  #000000;
#         }    #T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row2_col0 {
#             background-color:  #ffcccc;
#             color:  #000000;
#         }    #T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row2_col1 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row3_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row3_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }</style><table id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1" ><thead>    <tr>        <th class="index_name level0" >target</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >cp</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1level0_row0" class="row_heading level0 row0" >asymptomatic</th>
#                         <td id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row0_col0" class="data row0 col0" >74.950000</td>
#                         <td id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row0_col1" class="data row0 col1" >23.330000</td>
#             </tr>
#             <tr>
#                         <th id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1level0_row1" class="row_heading level0 row1" >atypical angina</th>
#                         <td id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row1_col0" class="data row1 col0" >6.670000</td>
#                         <td id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row1_col1" class="data row1 col1" >25.620000</td>
#             </tr>
#             <tr>
#                         <th id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1level0_row2" class="row_heading level0 row2" >non-anginal pain</th>
#                         <td id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row2_col0" class="data row2 col0" >13.130000</td>
#                         <td id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row2_col1" class="data row2 col1" >41.300000</td>
#             </tr>
#             <tr>
#                         <th id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1level0_row3" class="row_heading level0 row3" >typical angina</th>
#                         <td id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row3_col0" class="data row3 col0" >5.250000</td>
#                         <td id="T_bc7a1fdc_b2e3_11ee_94e4_faffc20b68f1row3_col1" class="data row3 col1" >9.750000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# As we can see from above plot 41% of the chest pain type of the heart disease patients have non-anginal pain.

# %% [markdown]
# ### Distribution of Rest ECG

# %%
# plotting normal patients
fig = plt.figure(figsize=(15, 5))
ax1 = plt.subplot2grid((1, 2), (0, 0))
sns.countplot(data=attr_0, x='restecg')  # Specify 'data' parameter and use 'x' to specify the column
plt.title('REST ECG OF NORMAL PATIENTS', fontsize=15, weight='bold')

# plotting heart patients
ax2 = plt.subplot2grid((1, 2), (0, 1))
sns.countplot(data=attr_1, x='restecg', palette='viridis')  # Specify 'data' parameter and use 'x' to specify the column
plt.title('REST ECG OF HEART PATIENTS', fontsize=15, weight='bold')
plt.show()

# %%
#Exploring the Heart Disease patients based on REST ECG
plot_criteria= ['restecg', 'target']
cm = sns.light_palette("red", as_cmap=True)
(round(pd.crosstab(df[plot_criteria[0]], df[plot_criteria[1]], normalize='columns') * 100,2)).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1row0_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1row0_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1row1_col0 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1row1_col1 {
#             background-color:  #ff4949;
#             color:  #000000;
#         }    #T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1row2_col0 {
#             background-color:  #ff4646;
#             color:  #000000;
#         }    #T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1row2_col1 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1" ><thead>    <tr>        <th class="index_name level0" >target</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >restecg</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1level0_row0" class="row_heading level0 row0" >ST-T wave abnormality</th>
#                         <td id="T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1row0_col0" class="data row0 col0" >2.420000</td>
#                         <td id="T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1row0_col1" class="data row0 col1" >0.570000</td>
#             </tr>
#             <tr>
#                         <th id="T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1level0_row1" class="row_heading level0 row1" >left ventricular hypertrophy</th>
#                         <td id="T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1row1_col0" class="data row1 col0" >57.170000</td>
#                         <td id="T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1row1_col1" class="data row1 col1" >40.340000</td>
#             </tr>
#             <tr>
#                         <th id="T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1level0_row2" class="row_heading level0 row2" >normal</th>
#                         <td id="T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1row2_col0" class="data row2 col0" >40.400000</td>
#                         <td id="T_d7f003b2_b2e3_11ee_94e4_faffc20b68f1row2_col1" class="data row2 col1" >59.080000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# An electrocardiogram records the electrical signals in your heart. It's a common test used to detect heart problems and monitor the heart's status in many situations. Electrocardiograms — also called ECGs or EKGs. but ECG has limits. It measures heart rate and rhythm—but it doesn’t necessarily show blockages in the arteries.Thats why in this dataset around 59% heart disease patients have normal ECG

# %% [markdown]
# ### Distribution of ST Slope

# %%
# plotting normal patients
fig = plt.figure(figsize=(15, 5))
ax1 = plt.subplot2grid((1, 2), (0, 0))
sns.countplot(data=attr_0, x='slope')  # Specify 'data' parameter and use 'x' to specify the column
plt.title('ST SLOPE OF NORMAL PATIENTS', fontsize=15, weight='bold')

# plotting heart patients
ax2 = plt.subplot2grid((1, 2), (0, 1))
sns.countplot(data=attr_1, x='slope', palette='viridis')  # Specify 'data' parameter and use 'x' to specify the column
plt.title('ST SLOPE OF HEART PATIENTS', fontsize=15, weight='bold')
plt.show()

# %%
#Exploring the Heart Disease patients based on ST Slope
plot_criteria= ['slope', 'target']
cm = sns.light_palette("red", as_cmap=True)
(round(pd.crosstab(df[plot_criteria[0]], df[plot_criteria[1]], normalize='columns') * 100,2)).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_f36fea94_b2e3_11ee_94e4_faffc20b68f1row0_col0 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_f36fea94_b2e3_11ee_94e4_faffc20b68f1row0_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_f36fea94_b2e3_11ee_94e4_faffc20b68f1row1_col0 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_f36fea94_b2e3_11ee_94e4_faffc20b68f1row1_col1 {
#             background-color:  #ff8585;
#             color:  #000000;
#         }    #T_f36fea94_b2e3_11ee_94e4_faffc20b68f1row2_col0 {
#             background-color:  #ffa0a0;
#             color:  #000000;
#         }    #T_f36fea94_b2e3_11ee_94e4_faffc20b68f1row2_col1 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_f36fea94_b2e3_11ee_94e4_faffc20b68f1" ><thead>    <tr>        <th class="index_name level0" >target</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >slope</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f36fea94_b2e3_11ee_94e4_faffc20b68f1level0_row0" class="row_heading level0 row0" >downsloping</th>
#                         <td id="T_f36fea94_b2e3_11ee_94e4_faffc20b68f1row0_col0" class="data row0 col0" >9.290000</td>
#                         <td id="T_f36fea94_b2e3_11ee_94e4_faffc20b68f1row0_col1" class="data row0 col1" >5.350000</td>
#             </tr>
#             <tr>
#                         <th id="T_f36fea94_b2e3_11ee_94e4_faffc20b68f1level0_row1" class="row_heading level0 row1" >flat</th>
#                         <td id="T_f36fea94_b2e3_11ee_94e4_faffc20b68f1row1_col0" class="data row1 col0" >64.650000</td>
#                         <td id="T_f36fea94_b2e3_11ee_94e4_faffc20b68f1row1_col1" class="data row1 col1" >30.210000</td>
#             </tr>
#             <tr>
#                         <th id="T_f36fea94_b2e3_11ee_94e4_faffc20b68f1level0_row2" class="row_heading level0 row2" >upsloping</th>
#                         <td id="T_f36fea94_b2e3_11ee_94e4_faffc20b68f1row2_col0" class="data row2 col0" >26.060000</td>
#                         <td id="T_f36fea94_b2e3_11ee_94e4_faffc20b68f1row2_col1" class="data row2 col1" >64.440000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Flat is positive sign as 64.65% of the normal patients have flat sloping where as 64.44% heart patients have upsloping.

# %% [markdown]
# ### Distribution of Numerical features

# %%
sns.pairplot(df, hue = 'target', vars = ['age', 'trestbps', 'chol'] )

# %%
sns.scatterplot(x = 'trestbps', y = 'chol', hue = 'target', data = df)

# %%
sns.scatterplot(x = 'trestbps', y = 'age', hue = 'target', data = df)
