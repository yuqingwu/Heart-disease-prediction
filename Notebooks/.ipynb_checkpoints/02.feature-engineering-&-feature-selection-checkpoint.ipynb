# %% [markdown]
# ## Dependencies loading

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Project setup

# %%
raw_input_data_path = "../data/input"
preprocessed_output_data_path = "../data/output"

# %% [markdown]
# ## Load dataset

# %%
df_train = pd.read_csv(f"{preprocessed_output_data_path}/train.csv", index_col=0)
df_test = pd.read_csv(f"{preprocessed_output_data_path}/test.csv", index_col=0)

# %%
df_train.head()
# Out:
#      age     sex                cp  trestbps  chol    fbs  \
# 166   56    Male      asymptomatic       132   184  False
# 41    54    Male  non-anginal pain       120   258  False
# 763   58  Female    typical angina       150   283   True
# 826   42    Male  non-anginal pain       130   180  False
# 936   43    Male  non-anginal pain       130   315  False
#
#                           restecg  thalach exang  oldpeak      slope  ca  \
# 166  left ventricular hypertrophy      105   yes      2.1       flat   1
# 41   left ventricular hypertrophy      147    no      0.4       flat   0
# 763  left ventricular hypertrophy      162    no      1.0  upsloping   0
# 826                        normal      150    no      0.0  upsloping   0
# 936                        normal      162    no      1.9  upsloping   1
#
#                   thal  target
# 166       fixed defect       0
# 41   reversable defect       1
# 763             normal       1
# 826             normal       1
# 936             normal       1

# %%
df_test.head()
# Out:
#      age     sex                cp  trestbps  chol    fbs  \
# 886   61    Male      asymptomatic       120   260  False
# 516   60    Male      asymptomatic       130   206  False
# 362   43  Female  non-anginal pain       122   213  False
# 177   64    Male      asymptomatic       120   246  False
# 11    43  Female      asymptomatic       132   341   True
#
#                           restecg  thalach exang  oldpeak        slope  ca  \
# 886                        normal      140   yes      3.6         flat   1
# 516  left ventricular hypertrophy      132   yes      2.4         flat   2
# 362                        normal      165    no      0.2         flat   0
# 177  left ventricular hypertrophy       96   yes      2.2  downsloping   1
# 11   left ventricular hypertrophy      136   yes      3.0         flat   0
#
#                   thal  target
# 886  reversable defect       0
# 516  reversable defect       0
# 362             normal       1
# 177             normal       0
# 11   reversable defect       0

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# #### One-Hot Encoding

# %%
df_train = pd.get_dummies(df_train, dtype = int)
df_train.head()
# Out:
#      age  trestbps  chol    fbs  thalach  oldpeak  ca  target  sex_Female  \
# 166   56       132   184  False      105      2.1   1       0           0
# 41    54       120   258  False      147      0.4   0       1           0
# 763   58       150   283   True      162      1.0   0       1           1
# 826   42       130   180  False      150      0.0   0       1           0
# 936   43       130   315  False      162      1.9   1       1           0
#
#      sex_Male  ...  restecg_left ventricular hypertrophy  restecg_normal  \
# 166         1  ...                                     1               0
# 41          1  ...                                     1               0
# 763         0  ...                                     1               0
# 826         1  ...                                     0               1
# 936         1  ...                                     0               1
#
#      exang_no  exang_yes  slope_downsloping  slope_flat  slope_upsloping  \
# 166         0          1                  0           1                0
# 41          1          0                  0           1                0
# 763         1          0                  0           0                1
# 826         1          0                  0           0                1
# 936         1          0                  0           0                1
#
#      thal_fixed defect  thal_normal  thal_reversable defect
# 166                  1            0                       0
# 41                   0            0                       1
# 763                  0            1                       0
# 826                  0            1                       0
# 936                  0            1                       0
#
# [5 rows x 25 columns]

# %%
df_test = pd.get_dummies(df_test, dtype = int)
df_test.head()
# Out:
#      age  trestbps  chol    fbs  thalach  oldpeak  ca  target  sex_Female  \
# 886   61       120   260  False      140      3.6   1       0           0
# 516   60       130   206  False      132      2.4   2       0           0
# 362   43       122   213  False      165      0.2   0       1           1
# 177   64       120   246  False       96      2.2   1       0           0
# 11    43       132   341   True      136      3.0   0       0           1
#
#      sex_Male  ...  restecg_left ventricular hypertrophy  restecg_normal  \
# 886         1  ...                                     0               1
# 516         1  ...                                     1               0
# 362         0  ...                                     0               1
# 177         1  ...                                     1               0
# 11          0  ...                                     1               0
#
#      exang_no  exang_yes  slope_downsloping  slope_flat  slope_upsloping  \
# 886         0          1                  0           1                0
# 516         0          1                  0           1                0
# 362         1          0                  0           1                0
# 177         0          1                  1           0                0
# 11          0          1                  0           1                0
#
#      thal_fixed defect  thal_normal  thal_reversable defect
# 886                  0            0                       1
# 516                  0            0                       1
# 362                  0            1                       0
# 177                  0            1                       0
# 11                   0            0                       1
#
# [5 rows x 25 columns]

# %%
print(df_train.shape, df_test.shape)
# Out:
# (814, 25) (204, 25)

# %% [markdown]
# #### Feature normalization

# %% [markdown]
# In this step we will normalize all the numeric feature in the range of 0 to 1

# %%
# training data
scaler = MinMaxScaler()
df_train[['age','trestbps','chol','thalach','oldpeak','ca']] = scaler.fit_transform(df_train[['age','trestbps','chol','thalach','oldpeak','ca']])
df_train.head()
# Out:
#           age  trestbps      chol    fbs   thalach   oldpeak    ca  target  \
# 166  0.562500  0.358491  0.132420  False  0.259542  0.338710  0.25       0
# 41   0.520833  0.245283  0.301370  False  0.580153  0.064516  0.00       1
# 763  0.604167  0.528302  0.358447   True  0.694656  0.161290  0.00       1
# 826  0.270833  0.339623  0.123288  False  0.603053  0.000000  0.00       1
# 936  0.291667  0.339623  0.431507  False  0.694656  0.306452  0.25       1
#
#      sex_Female  sex_Male  ...  restecg_left ventricular hypertrophy  \
# 166           0         1  ...                                     1
# 41            0         1  ...                                     1
# 763           1         0  ...                                     1
# 826           0         1  ...                                     0
# 936           0         1  ...                                     0
#
#      restecg_normal  exang_no  exang_yes  slope_downsloping  slope_flat  \
# 166               0         0          1                  0           1
# 41                0         1          0                  0           1
# 763               0         1          0                  0           0
# 826               1         1          0                  0           0
# 936               1         1          0                  0           0
#
#      slope_upsloping  thal_fixed defect  thal_normal  thal_reversable defect
# 166                0                  1            0                       0
# 41                 0                  0            0                       1
# 763                1                  0            1                       0
# 826                1                  0            1                       0
# 936                1                  0            1                       0
#
# [5 rows x 25 columns]

# %%
# test data
scaler = MinMaxScaler()
df_test[['age','trestbps','chol','thalach','oldpeak','ca']] = scaler.fit_transform(df_test[['age','trestbps','chol','thalach','oldpeak','ca']])
df_test.head()
# Out:
#           age  trestbps      chol    fbs   thalach   oldpeak    ca  target  \
# 886  0.666667  0.302326  0.451049  False  0.526718  0.818182  0.25       0
# 516  0.645833  0.418605  0.262238  False  0.465649  0.545455  0.50       0
# 362  0.291667  0.325581  0.286713  False  0.717557  0.045455  0.00       1
# 177  0.729167  0.302326  0.402098  False  0.190840  0.500000  0.25       0
# 11   0.291667  0.441860  0.734266   True  0.496183  0.681818  0.00       0
#
#      sex_Female  sex_Male  ...  restecg_left ventricular hypertrophy  \
# 886           0         1  ...                                     0
# 516           0         1  ...                                     1
# 362           1         0  ...                                     0
# 177           0         1  ...                                     1
# 11            1         0  ...                                     1
#
#      restecg_normal  exang_no  exang_yes  slope_downsloping  slope_flat  \
# 886               1         0          1                  0           1
# 516               0         0          1                  0           1
# 362               1         1          0                  0           1
# 177               0         0          1                  1           0
# 11                0         0          1                  0           1
#
#      slope_upsloping  thal_fixed defect  thal_normal  thal_reversable defect
# 886                0                  0            0                       1
# 516                0                  0            0                       1
# 362                0                  0            1                       0
# 177                0                  0            1                       0
# 11                 0                  0            0                       1
#
# [5 rows x 25 columns]
